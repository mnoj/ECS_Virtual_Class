# %% [markdown]
# # 📚 Course Materials Index
# Welcome to the "Komunikazio Sistema Elektronikoak"! Click the links below to start each lesson exercise.
#
# ### 📘 Chapter 1: System Design and Specifications – Link Budget
# ---
#
# * [ADC and Sampling](./01_01_ADC.ipynb)
# * [NF and Cascaded NF](./01_02_Cascaded_NF.ipynb)
# * [Interception Point](./01_03_IP3.ipynb)
# * [AMPS Sensitivity](./01_04_AMPS_Sensitivity.ipynb)
#
# ### 📘 RF and Microwave Components – Passive, Active, and Matching Networks

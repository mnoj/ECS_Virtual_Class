# %% [markdown]
# # Intermodulation Products
#
# Non-linear devices (such as LNAs, mixers, and VCOs) can introduce critical effects like harmonics, interferences, and saturation. These non-linearities generate intermodulation products (IM) of various orders. Spurious responses refer to unwanted frequencies that, if strong enough, can produce a demodulated signal. Harmonic mixing, a result of nonlinearity, is the primary cause of these spurious responses. This is the example for a stage with \( f_{1}=5 \, \text{MHz} \) and \( f_{2}=6 \, \text{MHz} \).
#
# | **Order** | **Product Type**                   | **Mathematical Formula**          | **Frequency (MHz)** |
# |-----------|-------------------------------------|-----------------------------------|---------------------|
# | 2nd       | IMD2 (Difference)                  | $$ f_2 - f_1 $$                   | 1.00                |
# | 2nd       | Harmonic                            | $$ 2f_1 $$                        | 10.00               |
# | 2nd       | IMD2 (Sum)                          | $$ f_1 + f_2 $$                   | 11.00               |
# | 2nd       | Harmonic                            | $$ 2f_2 $$                        | 12.00               |
# | 3rd       | IMD3 (Lower Sideband)              | $$ 2f_1 - f_2 $$                  | 4.00                |
# | 3rd       | IMD3 (Upper Sideband)              | $$ 2f_2 - f_1 $$                  | 7.00                |
# | 3rd       | Harmonic                            | $$ 3f_1 $$                        | 15.00               |
# | 3rd       | IMD3 (Lower Sum)                   | $$ f_1 + f_2 $$                   | 16.00               |
# | 3rd       | IMD3 (Upper Sum)                   | $$ 2f_2 + f_1 $$                  | 17.00               |
# | 3rd       | Harmonic                            | $$ 3f_2 $$                        | 18.00               |
#
# ## 1. Intercept Point
#
# The "Intercept Point" is a figure of merit used to characterize a device's linearity. It is the theoretical power level at which the distortion product equals the fundamental signal. In the **Third-Order Intercept (IP3)**, as you saw in the simulation, for every \( 1 \, \text{dB} \) of input power increase, the \( IMD3 \) increases by \( 3 \, \text{dB} \).
#
# For a device with gain \( G \) (in dB), the output power is:
#
# $$
# P_{\text{out}} = P_{\text{in}} + G
# $$
#
# The **IIP3** (Input IP3) is the point where the fundamental and \( IMD3 \) lines cross at the input side. Similarly, the **OIP3** (Output IP3) is the point where the fundamental and \( IMD3 \) lines cross at the output. If you measure \( P_{\text{out}} \) and the suppression \( \Delta_{IM3} \) (in dBc), you can find **OIP3** using:
#
# $$
# OIP3 = P_{\text{out}} + \frac{\Delta_{IM3}}{2}
# $$
#
# Similarly, **IIP3** can be found using:
#
# $$
# IIP3 = P_{\text{in}} + \frac{\Delta_{IM3}}{2}
# $$
#
# Then, the **output power** of the **IMD3** (third-order intermodulation distortion) product is related to the input power and the **IP3** of the system. The formula to estimate the output power of the IMD3 product is:
#
# $$
# P_{\text{IMD3}} = 3 \cdot P_{out} (dBm)-2 \cdot OIP3(dBm)
# $$
#
# Where:
# - $P_{\text{IMD3}}$ is the output power of the third-order intermodulation distortion (IMD3) product in dBm.
# - $ P_{\text{out}}$ is the ouput power to the system in dBm.
# - $ IP3_{\text{dBm}}$ is the third-order intercept point (IP3) of the system in dBm.
#
# This formula accounts for the fact that, for every 1 dB increase in input power, the IMD3 power increases by 3 dB, reflecting the system's nonlinearity.
#
# Finally, the 1dB Compression Point (P1dB) is a key measure of an amplifier's linearity. It marks the power level where the actual output power is 1 dB lower than the ideal (linear) output power.
#
# ## 2. Cascaded IP3
#
# In a receiver chain, each stage contributes non-linear distortion. As signals pass through amplifiers and mixers, they are amplified, increasing the likelihood of driving subsequent stages into nonlinearity. The intercept point formulas must be calculated using linear power (Watts or mWatts) rather than logarithmic units (dBm). The total system **IIP3** is calculated by summing the reciprocal of each stage's intercept point, scaled by the gain of the preceding stages. For a **5-stage system**:
#
# $$
# \frac{1}{IIP3_{\text{total}}} = \frac{1}{IIP3_1} + \frac{G_1}{IIP3_2} + \frac{G_1 G_2}{IIP3_3} + \frac{G_1 G_2 G_3}{IIP3_4} + \frac{G_1 G_2 G_3 G_4}{IIP3_5}
# $$
#
# ## 3. Key Observations for Design
#
# - **Gain-Linearity Trade-off**: Increasing the Gain (\( G \)) of an early stage (like an **LNA**) improves the Noise Figure, but it degrades the total **IIP3**. This happens because a higher **\( G_1 \)** amplifies the distortion contributions.
#
# - **Passive Stages**: Components like filters (S1 or S4 in your code) often have very high **IIP3** (e.g., 100 dBm). Their contribution to the reciprocal sum becomes nearly zero, essentially "passing through" the linearity of the previous stage minus their insertion loss.
#
# - **The Bottleneck**: The stage where the **IIP3** curve drops most sharply is your linearity bottleneck. To improve the system's **IIP3**, you must either reduce the gain of the preceding stage or select a component with a higher individual **IIP3** for that position.

# %%
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets
from ipywidgets import VBox, HBox, interactive_output

def plot_perfect_mixer_purple(f_rf, f_lo, p_rf, p_lo):
    # --- 1. Calculations ---
    f_if_diff = abs(f_rf - f_lo)
    f_if_sum = f_rf + f_lo
    
    # In a perfect mixer, output power equals RF power (0dB conversion loss)
    p_if = p_rf 

    # --- 2. Plotting ---
    plt.figure(figsize=(12, 6))
    
    def draw_spectral_line(f, p, color, label, marker='o'):
        plt.vlines(f, -100, p, colors=color, linewidth=4, label=label)
        plt.plot(f, p, marker, color=color, markersize=10)
        # Add numeric value label
        plt.text(f, p + 2, f'{p} dBm\n{f} MHz', ha='center', va='bottom', 
                 color=color, fontsize=9, fontweight='bold')

    # Input Signals (Green and Blue)
    draw_spectral_line(f_rf, p_rf, '#2ecc71', f'RF Input ({f_rf} MHz)')
    draw_spectral_line(f_lo, p_lo, '#3498db', f'LO Input ({f_lo} MHz)')
    
    # Output Signals (Two shades of Purple)
    # Difference Frequency: Deep Purple
    draw_spectral_line(f_if_diff, p_if, '#6c3483', f'IF Output (Diff: |RF-LO| = {f_if_diff} MHz)')
    # Sum Frequency: Bright Purple/Lavender
    draw_spectral_line(f_if_sum, p_if, '#af7ac5', f'IF Output (Sum: RF+LO = {f_if_sum} MHz)')

    plt.title("Ideal Mixer", fontsize=14, fontweight='bold')
    plt.xlabel("Frequency (MHz)")
    plt.ylabel("Power (dBm)")
    plt.grid(True, linestyle=':', alpha=0.6)
    plt.ylim(-100, max(p_lo, p_rf) + 25) # Increased headroom for labels
    plt.xlim(0, f_if_sum + 50)
    plt.legend(loc='upper right', frameon=True, shadow=True)
    
    # Text notes for students
    plt.text(f_if_diff, p_if + 12, 'Down-conversion', ha='center', color='#6c3483', fontweight='bold')
    plt.text(f_if_sum, p_if + 12, 'Up-conversion', ha='center', color='#af7ac5', fontweight='bold')

    plt.show()

# --- UI Controls ---
f_rf_s = widgets.IntSlider(min=100, max=1000, value=900, description='f_RF (MHz)')
f_lo_s = widgets.IntSlider(min=100, max=1000, value=830, description='f_LO (MHz)')
p_rf_s = widgets.IntSlider(min=-60, max=-10, value=-30, description='P_RF (dBm)')
p_lo_s = widgets.IntSlider(min=0, max=20, value=13, description='P_LO (dBm)')

ui = VBox([HBox([f_rf_s, f_lo_s]), HBox([p_rf_s, p_lo_s])])
out = interactive_output(plot_perfect_mixer_purple, {'f_rf': f_rf_s, 'f_lo': f_lo_s, 'p_rf': p_rf_s, 'p_lo': p_lo_s})

display(ui, out)
# Out:
# ...
# Output()

# %%
import ipywidgets as widgets
from IPython.display import display, HTML
from ipywidgets import interactive_output, VBox, HBox
import numpy as np
import matplotlib.pyplot as plt

def plotDynamicNonlinearAnalysis(f1, f2, pOut):
    plt.close('all')
    # Ensure f1 is always the lower frequency
    fLow, fHigh = min(f1, f2), max(f1, f2)
    
    # 2nd Order Products
    fImd2Diff = fHigh - fLow
    fImd2Sum = fLow + fHigh
    f2f1, f2f2 = 2*fLow, 2*fHigh
    
    # 3rd Order Products
    fImd3DiffL = 2*fLow - fHigh
    fImd3DiffH = 2*fHigh - fLow
    fImd3SumL = 2*fLow + fHigh
    fImd3SumH = 2*fHigh + fLow
    f3f1, f3f2 = 3*fLow, 3*fHigh
    
    # Power Levels
    pImd2 = pOut - 40     
    pImd3 = pOut - 55     

    # --- Plotting ---
    plt.figure(figsize=(12, 6))
    
    def drawTone(f, p, color, label, eqn, lw=4, ls='-'):
        if f > 0:
            plt.vlines(f, -140, p, colors=color, linewidth=lw, label=label, linestyles=ls)
            plt.plot(f, p, 'o', color=color, markersize=7)
            plt.text(f, p + 2, eqn, color=color, fontsize=9, ha='center', va='bottom', fontweight='bold')

    drawTone(fLow, pOut, '#3498db', 'Fundamentals', 'f1', lw=5)
    drawTone(fHigh, pOut, '#3498db', '', 'f2')
    drawTone(fImd2Diff, pImd2, '#f39c12', '2nd Order Mixing', 'f2-f1')
    drawTone(fImd2Sum, pImd2, '#f39c12', '', 'f1+f2')
    drawTone(f2f1, pImd2, '#f1c40f', '2nd Order Harmonics', '2f1', ls='--')
    drawTone(f2f2, pImd2, '#f1c40f', '', '2f2', ls='--')
    drawTone(fImd3DiffL, pImd3, '#e74c3c', '3rd Order Mixing Diff', '2f1-f2')
    drawTone(fImd3DiffH, pImd3, '#e74c3c', '', '2f2-f1')
    drawTone(fImd3SumL, pImd3, '#c0392b', '3rd Order Mixing Sum', '2f1+f2')
    drawTone(fImd3SumH, pImd3, '#c0392b', '', '2f2+f1')
    drawTone(f3f1, pImd3, '#943126', '3rd Order Harmonics', '3f1', ls='--')
    drawTone(f3f2, pImd3, '#943126', '', '3f2', ls='--')

    plt.title(f"Nonlinear Spectral Map")
    plt.xlabel("Frequency (MHz)")
    plt.ylabel("Power (dBm)")
    plt.xlim(0, max(f3f2, fImd3SumH) + 5)
    plt.ylim(-140, max(pOut + 20, 10))
    plt.grid(True, linestyle=':', alpha=0.6)
    plt.show()

    # --- Table Generation ---
    results = [
        ("Fundamental f1", fLow, pOut),
        ("Fundamental f2", fHigh, pOut),
        ("IM2 (f2-f1)", fImd2Diff, pImd2),
        ("IM2 (f1+f2)", fImd2Sum, pImd2),
        ("Harmonic 2f1", f2f1, pImd2),
        ("Harmonic 2f2", f2f2, pImd2),
        ("IM3 (2f1-f2)", fImd3DiffL, pImd3),
        ("IM3 (2f2-f1)", fImd3DiffH, pImd3),
        ("IM3 (2f1+f2)", fImd3SumL, pImd3),
        ("IM3 (2f2+f1)", fImd3SumH, pImd3),
        ("Harmonic 3f1", f3f1, pImd3),
        ("Harmonic 3f2", f3f2, pImd3),
    ]

    htmlTable = "<table style='width:50%; border: 1px solid black; border-collapse: collapse;'>"
    htmlTable += "<tr style='background-color: #f2f2f2;'><th>Component</th><th>Frequency (MHz)</th><th>Power (dBm)</th></tr>"
    for comp, freq, pwr in results:
        if freq > 0:
            htmlTable += f"<tr><td style='border: 1px solid #ddd; padding: 8px;'>{comp}</td>"
            htmlTable += f"<td style='border: 1px solid #ddd; padding: 8px;'>{freq:.2f}</td>"
            htmlTable += f"<td style='border: 1px solid #ddd; padding: 8px;'>{pwr:.1f}</td></tr>"
    htmlTable += "</table>"
    
    display(HTML(htmlTable))

# --- UI Controls ---
f1w = widgets.FloatSlider(min=1.0, max=2000.0, value=5.0, step=0.01, description='f1 (MHz)')
f2w = widgets.FloatSlider(min=1.0, max=2000.0, value=6.0, step=0.01, description='f2 (MHz)')
pOutw = widgets.IntSlider(min=-40, max=10, value=-10, description='P fund (dBm)')

ui = VBox([HBox([f1w, f2w]), pOutw])
out = interactive_output(plotDynamicNonlinearAnalysis, {'f1': f1w, 'f2': f2w, 'pOut': pOutw})

display(ui, out)
# Out:
# ...
# Output()

# %%
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets
from ipywidgets import VBox, HBox, interactive_output
from IPython.display import display

# Ensure plots render correctly
# %matplotlib inline

def plot_ip3_corrected(gain, iip3, p_in_val):
    # --- 1. THEORETICAL CALCULATION ---
    oip3 = iip3 + gain
    oip3_w.value = oip3
    
    # --- 2. Transfer Curve Logic ---
    p_in_axis = np.linspace(-60, 40, 100)
    p_out_fund_axis = p_in_axis + gain
    p_out_imd3_axis = 3 * (p_in_axis + gain) - 2 * oip3
    
    # --- 3. Current Point Calculations ---
    p_out_fund_val = p_in_val + gain
    p_out_imd3_val = 3 * p_out_fund_val - 2 * oip3
    suppression = p_out_fund_val - p_out_imd3_val

    # --- 4. Plotting ---
    plt.close('all') 
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 8), gridspec_kw={'width_ratios': [1.5, 1]})
    
    # LEFT PLOT: Intercept Point Visualization
    ax1.plot(p_in_axis, p_out_fund_axis, label='Fundamental (Slope=1)', color='#3498db', lw=3)
    ax1.plot(p_in_axis, p_out_imd3_axis, label='IMD3 Product (Slope=3)', color='#e74c3c', lw=3)
    
    # INTERCEPT POINT (Black)
    ax1.plot(iip3, oip3, 'ko', markersize=10, label=f'Intercept Point ({oip3:.1f} dBm)')
    ax1.text(iip3 + 2, oip3 - 5, f'IIP3: {iip3:.1f} dBm\nOIP3: {oip3:.1f} dBm', 
             fontweight='bold', bbox=dict(facecolor='white', alpha=0.7, edgecolor='black'))
    
    # OPERATING POINTS (Blue and Red)
    ax1.plot(p_in_val, p_out_fund_val, 'bo', markersize=8)
    ax1.plot(p_in_val, p_out_imd3_val, 'ro', markersize=8)
    ax1.vlines(p_in_val, -140, p_out_fund_val, linestyles='--', alpha=0.4, color='gray')
    
    # Labels for Operating Points
    ax1.text(p_in_val - 2, p_out_fund_val + 4, f'Pout: {p_out_fund_val:.1f} dBm', 
             color='blue', fontweight='bold', ha='right')
    ax1.text(p_in_val - 2, p_out_imd3_val - 8, f'IMD3: {p_out_imd3_val:.1f} dBm', 
             color='red', fontweight='bold', ha='right')
    ax1.text(p_in_val, -120, f'Pin: {p_in_val:.1f}', color='black', ha='center', fontweight='bold')
    
    ax1.set_title(f'Theoretical Intercept: OIP3 = {oip3:.1f} dBm', fontsize=14, fontweight='bold')
    ax1.set_xlabel('Input Power ($P_{in}$) [dBm]')
    ax1.set_ylabel('Output Power ($P_{out}$) [dBm]')
    ax1.set_xlim(-60, 45)
    ax1.set_ylim(-125, 85)
    ax1.grid(True, alpha=0.3)
    ax1.legend(loc='lower right')

    # RIGHT PLOT: Spectrum View
    freqs = [9, 10, 11, 12]
    # Draw bars
    ax2.vlines(freqs[1:3], -200, p_out_fund_val, colors='#3498db', lw=10) 
    ax2.vlines([freqs[0], freqs[3]], -200, p_out_imd3_val, colors='#e74c3c', lw=8)
    
    # ADD POWER VALUES TO THE BARS
    # Fundamental peaks
    for f in freqs[1:3]:
        ax2.text(f, p_out_fund_val + 2, f'{p_out_fund_val:.1f} dBm', color='#2980b9', 
                 ha='center', fontweight='bold', fontsize=10)
    # IMD3 peaks
    for f in [freqs[0], freqs[3]]:
        ax2.text(f, p_out_imd3_val + 2, f'{p_out_imd3_val:.1f} dBm', color='#c0392b', 
                 ha='center', fontweight='bold', fontsize=10)
    
    if suppression > 0:
        ax2.annotate('', xy=(11.5, p_out_imd3_val), xytext=(11.5, p_out_fund_val),
                     arrowprops=dict(arrowstyle='<->', color='green', lw=2))
        ax2.text(11.7, (p_out_fund_val + p_out_imd3_val)/2, f'Δ = {suppression:.1f} dBc', 
                 color='green', fontweight='bold', va='center')

    ax2.set_title(f'Spectrum Result (Pin: {p_in_val:.1f} dBm)', fontweight='bold')
    ax2.set_xticks(freqs)
    ax2.set_xticklabels(['$2f_1-f_2$', '$f_1$', '$f_2$', '$2f_2-f_1$'])
    ax2.set_ylim(-150, 85)
    ax2.grid(True, axis='y', alpha=0.3)

    plt.tight_layout()
    plt.show()

# --- UI CONTROLS ---
gain_w = widgets.FloatSlider(min=0.0, max=35.0, value=20.0, step=0.1, description='Gain (dB)')
iip3_w = widgets.FloatSlider(min=-10.0, max=50.0, value=20.0, step=0.1, description='IIP3 (dBm)')
oip3_w = widgets.FloatSlider(min=0.0, max=90.0, value=iip3_w.value + gain_w.value, step=0.1, description='OIP3 (dBm)', disabled=True)
pin_w = widgets.FloatSlider(min=-60.0, max=20.0, value=-20.0, step=0.5, description='Pin (dBm)')

ui = VBox([HBox([gain_w, iip3_w, oip3_w]), pin_w])
out = interactive_output(plot_ip3_corrected, {'gain': gain_w, 'iip3': iip3_w, 'p_in_val': pin_w})

display(ui, out)
# Out:
# ...
# Output()

# %%
import ipywidgets as widgets
from IPython.display import display, HTML
from ipywidgets import interactive_output, VBox, HBox
import numpy as np
import matplotlib.pyplot as plt

def dbmToMw(dbm):
    return 10**(dbm / 10.0)

def mwToDbm(mw):
    return 10 * np.log10(max(mw, 1e-18))

def calculateCascade(gList, iip3List):
    # To calculate system IIP3:
    # 1/IIP3_total = 1/IIP3_1 + G1/IIP3_2 + (G1*G2)/IIP3_3 + ...
    gLin = [10**(g/10.0) for g in gList]
    iip3Lin = [dbmToMw(i) for i in iip3List]
    
    invIip3Total = 0
    cumulativeGainLin = 1.0
    
    for i in range(len(iip3Lin)):
        # Add the contribution of the current stage referred to the input
        invIip3Total += cumulativeGainLin / iip3Lin[i]
        
        # Multiply cumulative gain by current stage gain for the NEXT stage calculation
        if i < len(gLin):
            cumulativeGainLin *= gLin[i]
            
    iip3TotalMw = 1 / max(invIip3Total, 1e-18)
    return mwToDbm(iip3TotalMw)

def updateDisplay(g1, i1, g2, i2, g3, i3, g4, i4, g5, i5, pinValue):
    plt.close('all')
    
    gains = [g1, g2, g3, g4, g5]
    iip3s = [i1, i2, i3, i4, i5]
    names = ['Filter/Ant', 'LNA', 'Mixer', 'IF Filter', 'IF Amp']
    
    # Calculate total system IIP3 using the correct cascading rule
    # Note: the gain list passed is one shorter than iip3 list for the internal loop logic
    totalIip3 = calculateCascade(gains[:-1], iip3s)
    totalGain = sum(gains)
    totalOip3 = totalIip3 + totalGain
    
    # 1. Fundamental Output Power
    poutFundamental = pinValue + totalGain
    
    # 2. Delta (Difference between Fundamental and IMD3 at output)
    deltaValue = 2 * (totalOip3 - poutFundamental)
    
    # 3. IMD3 Output Power
    poutImd3 = poutFundamental - deltaValue

    statusColor = "#c0392b" if poutImd3 > poutFundamental else "#27ae60"
    statusText = "DISTORTION OVER SIGNAL" if poutImd3 > poutFundamental else "Linear Region"

    display(HTML(f"""
    <div style="padding: 15px; border-left: 5px solid #2980b9; background-color: #ebf5fb; font-family: sans-serif; margin-bottom: 10px;">
        <h3 style="margin-top:0; color:#21618c;">System Intermodulation Analysis</h3>
        <p><b>Total System Gain (G):</b> {totalGain:.2f} dB</p>
        <p><b>System IIP3 / OIP3:</b> {totalIip3:.2f} dBm / {totalOip3:.2f} dBm</p>
        <hr>
        <p><b>Input Carrier Power (Pin):</b> {pinValue:.2f} dBm</p>
        <p style="font-size: 1.1em;"><b>Output Carrier Power (Pout):</b> <b>{poutFundamental:.2f} dBm</b></p>
        <p><b>Delta (ΔP):</b> {deltaValue:.2f} dB</p>
        <p style="font-size: 1.1em;"><b>IMD3 Output Power:</b> 
            <span style="color:{statusColor}; font-weight:bold;">{poutImd3:.2f} dBm</span>
        </p>
        <div style="margin-top:10px; font-weight:bold; color:{statusColor}; text-transform: uppercase;">
            Status: {statusText}
        </div>
    </div>
    """))

    plt.figure(figsize=(10, 4))
    # Correctly calculate cumulative IIP3 for plotting
    cumulativeResults = []
    for i in range(1, 6):
        # Slice gains to include only those PRECEDING the current stage
        val = calculateCascade(gains[:i-1], iip3s[:i])
        cumulativeResults.append(val)
        
    plt.plot(names, cumulativeResults, marker='D', lw=2, color='#21618c', markerfacecolor='white')
    
    for i, val in enumerate(cumulativeResults):
        plt.text(i, val + 1.5, f"{val:.2f}", ha='center', fontweight='bold')

    plt.title(f"Cascaded IIP3 Profile (Total: {totalIip3:.2f} dBm)")
    plt.ylabel("Cumulative IIP3 (dBm)")
    plt.grid(True, alpha=0.2)
    plt.tight_layout()
    plt.show()

def createStage(name, gInit, iInit):
    return [
        widgets.FloatSlider(min=-20, max=30, value=gInit, step=0.1, description=f'{name} G', continuous_update=False),
        widgets.FloatSlider(min=-10, max=100, value=iInit, step=0.1, description=f'{name} IIP3', continuous_update=False)
    ]

s1, s2, s3, s4, s5 = [createStage(n, g, i) for n, g, i in [
    ('S1', -2.3, 100), ('S2', 20.5, 16.5), ('S3', -7.3, 24.8), ('S4', -3.5, 100), ('S5', 22, 15.3)]]

pinSlider = widgets.FloatSlider(min=-100, max=20, value=-30, step=0.1, description='Pin (dBm)', continuous_update=False)

ui = VBox([HBox([s1[0], s1[1]]), HBox([s2[0], s2[1]]), HBox([s3[0], s3[1]]), 
           HBox([s4[0], s4[1]]), HBox([s5[0], s5[1]]), pinSlider])

params = {'g1':s1[0],'i1':s1[1],'g2':s2[0],'i2':s2[1],'g3':s3[0],'i3':s3[1],
          'g4':s4[0],'i4':s4[1],'g5':s5[0],'i5':s5[1], 'pinValue':pinSlider}

out = interactive_output(updateDisplay, params)
display(ui, out)
# Out:
# ...
# Output()
